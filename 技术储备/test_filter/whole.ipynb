# %%
import pandas as pd
import numpy as np

df=pd.read_csv('./merged_info.csv')

df
# "Mar de la Vida OJSC",
# "979893388",
# "Oceanfront Oasis Inc Carriers",
# "8327"
# Out:
#        Unnamed: 0            link_type    weight dataset_x  \
# 0               0            ownership  0.900140       MC1
# 1               1          partnership  0.845897       MC1
# 2               2          partnership  0.964876       MC1
# 3               3            ownership  0.964213       MC1
# 4               4  family_relationship  0.823486       MC1
# ...           ...                  ...       ...       ...
# 11064       11064  family_relationship  0.817772       MC1
# 11065       11065          partnership  0.873537       MC1
# 11066       11066          partnership  0.849333       MC1
# 11067       11067           membership  0.814217       MC1
# 11068       11068           membership  0.823890       MC1
#
#                          source         target  key source_type  \
# 0      Spanish Shrimp  Carriers          12744    0     company
# 1      Spanish Shrimp  Carriers       21323516    0     company
# 2      Spanish Shrimp  Carriers      290834957    0     company
# 3      Spanish Shrimp  Carriers        3506021    0     company
# 4      Spanish Shrimp  Carriers    Conventionâ    0     company
# ...                         ...            ...  ...         ...
# 11064         Ocano del Este SE  Mary Clements    0     unknown
# 11065   Norwegian Shrimp N.V. -       67261634    0     unknown
# 11066   Norwegian Shrimp N.V. -            344    0     unknown
# 11067      Malabar Sea Catch Sp            672    0     unknown
# 11068      Malabar Sea Catch Sp         449820    0     unknown
#
#       source_country   target_type  target_country
# 0           Nalakond  organization             NaN
# 1           Nalakond  organization             NaN
# 2           Nalakond  organization             NaN
# 3           Nalakond  organization             NaN
# 4           Nalakond       unknown             NaN
# ...              ...           ...             ...
# 11064            NaN        person  Country_271835
# 11065            NaN  organization             NaN
# 11066            NaN  organization             NaN
# 11067            NaN  organization             NaN
# 11068            NaN  organization             NaN
#
# [11069 rows x 11 columns]

# %% [markdown]
# # Ownership

# %%
arr1 = np.zeros((9,9))
o_table=pd.DataFrame(arr1, columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])

o_table_4points=pd.DataFrame(columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])
o_table_4points['organization_s'] = 0
o_table_4points['unknown_s'] = 0
o_table_4points.iloc[4] = 0
o_table_4points.iloc[8] = 0

o_cnt = 0

# %%
collect_4points = pd.DataFrame()
for row in df.iterrows():
    # print(row[1][1],row[1][7],row[1][9])
    if row[1][1] == 'ownership':
        o_cnt = o_cnt + 1
        o_table[row[1][7]+'_s'][row[1][9]+'_t'] = o_table[row[1][7]+'_s'][row[1][9]+'_t'] + 1

        if (row[1][4] == 'Mar de la Vida OJSC') or (row[1][5] == 'Mar de la Vida OJSC') or (row[1][4] == '979893388') or (row[1][5] == '979893388') or (row[1][4] == 'Oceanfront Oasis Inc Carriers') or (row[1][5] == 'Oceanfront Oasis Inc Carriers') or (row[1][4] == '8327') or (row[1][5] == '8327'):
            collect_4points = collect_4points.append(row[1])
            o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# 可疑点存在的边
collect_4points
# Out:
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2958558573.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = o_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
#        Unnamed: 0  link_type    weight dataset_x  \
# 868           868  ownership  0.817322       MC1
# 1315         1315  ownership  0.903510       MC1
# 2083         2083  ownership  0.834928       MC1
# 2327         2327  ownership  0.813712       MC1
# 2415         2415  ownership  0.891332       MC1
# 2416         2416  ownership  0.824839       MC1
# 2417         2417  ownership  0.907795       MC1
# 2458         2458  ownership  0.823488       MC1
# 4022         4022  ownership  0.804815       MC1
# 4315         4315  ownership  0.838258       MC1
# 4960         4960  ownership  0.836394       MC1
# 4969         4969  ownership  0.873781       MC1
# 4972         4972  ownership  0.924564       MC1
# 4998         4998  ownership  0.863397       MC1
# 4999         4999  ownership  0.847196       MC1
# 5010         5010  ownership  0.824144       MC1
# 5012         5012  ownership  0.813831       MC1
# 5016         5016  ownership  0.814809       MC1
# 5030         5030  ownership  0.826820       MC1
# 5031         5031  ownership  0.884165       MC1
# 5149         5149  ownership  0.859340       MC1
# 5344         5344  ownership  0.850426       MC1
# 5346         5346  ownership  0.835931       MC1
# 7416         7416  ownership  0.890057       MC1
# 8023         8023  ownership  0.819125       MC1
# 10135       10135  ownership  0.838920       MC1
# 10469       10469  ownership  0.811119       MC1
# 10532       10532  ownership  0.118600       MC1
#
#                                         source                         target  \
# 868                                          9                      979893388
# 1315      f21800ca-b3c9-404b-8438-3d75ea84c409                      979893388
# 2083                                        34                      979893388
# 2327                         Mar del Oeste Pic                      979893388
# 2415                                      8327                          weeks
# 2416                                      8327                       40213337
# 2417                                      8327                        cutters
# 2458                                     Coast                           8327
# 4022      17c99d9d-7049-4ebb-8a2a-f3d39cc42870                      979893388
# 4315                      Christopher Peterson                      979893388
# 4960                                 979893388  Oceanfront Oasis Inc Carriers
# 4969                                 979893388                            990
# 4972                                 979893388                  Kristin Jones
# 4998                                 979893388                      Ryabikova
# 4999                                 979893388                 Erica Hamilton
# 5010                                 979893388                John Barnes DDS
# 5012                                 979893388                   brianbushard
# 5016                                 979893388                   Miranda Long
# 5030                                 979893388                     ROBYN BECK
# 5031                                 979893388                   13d79d632036
# 5149                                   1972868                      979893388
# 5344                                   9590898                      979893388
# 5346                            Joshua Garrett                      979893388
# 7416                            Erica Hamilton                      979893388
# 8023                                      9345                      979893388
# 10135                      Ocean Fisheries Llc                      979893388
# 10469                      Mar de la Vida OJSC                      Jon White
# 10532  Seabreeze Foods Ltd. Corporation United                           8327
#
#        key             source_type source_country   target_type  \
# 868      0            organization            NaN  organization
# 1315     0                location            NaN  organization
# 2083     0            organization            NaN  organization
# 2327     1                 company   Vesperlandia  organization
# 2415     0            organization            NaN      movement
# 2416     0            organization            NaN  organization
# 2417     0            organization            NaN        vessel
# 2458     0                  vessel            NaN  organization
# 4022     0                location            NaN  organization
# 4315     0                  person        Oceanus  organization
# 4960     0            organization            NaN       unknown
# 4969     0            organization            NaN  organization
# 4972     0            organization            NaN        person
# 4998     0            organization            NaN       unknown
# 4999     0            organization            NaN        person
# 5010     0            organization            NaN        person
# 5012     0            organization            NaN       unknown
# 5016     0            organization            NaN        person
# 5030     0            organization            NaN       unknown
# 5031     0            organization            NaN       unknown
# 5149     0            organization            NaN  organization
# 5344     0            organization            NaN  organization
# 5346     0                  person   Arreciviento  organization
# 7416     0                  person        Marebak  organization
# 8023     0  political_organization            NaN  organization
# 10135    0                 unknown            NaN  organization
# 10469    0                 unknown            NaN        person
# 10532    0                 unknown            NaN  organization
#
#        target_country
# 868               NaN
# 1315              NaN
# 2083              NaN
# 2327              NaN
# 2415              NaN
# 2416              NaN
# 2417              NaN
# 2458              NaN
# 4022              NaN
# 4315              NaN
# 4960              NaN
# 4969              NaN
# 4972   Country_271835
# 4998              NaN
# 4999          Marebak
# 5010   Country_271835
# 5012              NaN
# 5016   Country_271835
# 5030              NaN
# 5031              NaN
# 5149              NaN
# 5344              NaN
# 5346              NaN
# 7416              NaN
# 8023              NaN
# 10135             NaN
# 10469      Polarisdom
# 10532             NaN

# %%
# 个数
o_table
# Out:
#                           company_s  event_s  location_s  movement_s  \
# company_t                      12.0      3.0        17.0         3.0
# event_t                         3.0      4.0         3.0         2.0
# location_t                     18.0      6.0        25.0         9.0
# movement_t                      5.0      0.0         2.0         4.0
# organization_t                 55.0      9.0        66.0         5.0
# person_t                       60.0     11.0        62.0         9.0
# political_organization_t        4.0      0.0        10.0         1.0
# vessel_t                        2.0      0.0         7.0         0.0
# unknown_t                      48.0      4.0        35.0         1.0
#
#                           organization_s  person_s  political_organization_s  \
# company_t                           44.0      20.0                       5.0
# event_t                              7.0      14.0                       1.0
# location_t                          49.0      27.0                       8.0
# movement_t                           3.0       6.0                       0.0
# organization_t                     289.0      87.0                      33.0
# person_t                           137.0       0.0                      31.0
# political_organization_t            16.0      11.0                      10.0
# vessel_t                            17.0       9.0                       0.0
# unknown_t                          142.0      81.0                       7.0
#
#                           vessel_s  unknown_s
# company_t                      2.0       30.0
# event_t                        0.0        9.0
# location_t                     2.0       38.0
# movement_t                     2.0        0.0
# organization_t                19.0      111.0
# person_t                      13.0       82.0
# political_organization_t       0.0        7.0
# vessel_t                      12.0        6.0
# unknown_t                      6.0       82.0

# %%
# 个数
o_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t                   1       0          2          0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                        0       0          0          0
#
#                           organization_s person_s political_organization_s  \
# company_t                              0      NaN                      NaN
# event_t                                0      NaN                      NaN
# location_t                             0      NaN                      NaN
# movement_t                             1      NaN                      NaN
# organization_t                         6        3                        1
# person_t                               4      NaN                      NaN
# political_organization_t               0      NaN                      NaN
# vessel_t                               1      NaN                      NaN
# unknown_t                              5        0                        0
#
#                          vessel_s  unknown_s
# company_t                     NaN          0
# event_t                       NaN          0
# location_t                    NaN          0
# movement_t                    NaN          0
# organization_t                  1          2
# person_t                      NaN          1
# political_organization_t      NaN          0
# vessel_t                      NaN          0
# unknown_t                       0          0

# %%
# 总数
print(o_cnt)
# Out:
# 1980

# %%
# 比例
o_table=(o_table/11069) * 100
o_table
# Out:
#                           company_s   event_s  location_s  movement_s  \
# company_t                  0.108411  0.027103    0.153582    0.027103
# event_t                    0.027103  0.036137    0.027103    0.018068
# location_t                 0.162616  0.054205    0.225856    0.081308
# movement_t                 0.045171  0.000000    0.018068    0.036137
# organization_t             0.496883  0.081308    0.596260    0.045171
# person_t                   0.542054  0.099377    0.560123    0.081308
# political_organization_t   0.036137  0.000000    0.090342    0.009034
# vessel_t                   0.018068  0.000000    0.063240    0.000000
# unknown_t                  0.433644  0.036137    0.316198    0.009034
#
#                           organization_s  person_s  political_organization_s  \
# company_t                       0.397507  0.180685                  0.045171
# event_t                         0.063240  0.126479                  0.009034
# location_t                      0.442678  0.243924                  0.072274
# movement_t                      0.027103  0.054205                  0.000000
# organization_t                  2.610895  0.785979                  0.298130
# person_t                        1.237691  0.000000                  0.280061
# political_organization_t        0.144548  0.099377                  0.090342
# vessel_t                        0.153582  0.081308                  0.000000
# unknown_t                       1.282862  0.731773                  0.063240
#
#                           vessel_s  unknown_s
# company_t                 0.018068   0.271027
# event_t                   0.000000   0.081308
# location_t                0.018068   0.343301
# movement_t                0.018068   0.000000
# organization_t            0.171651   1.002801
# person_t                  0.117445   0.740808
# political_organization_t  0.000000   0.063240
# vessel_t                  0.108411   0.054205
# unknown_t                 0.054205   0.740808

# %%
# 比例
o_table_4points=(o_table_4points/11069) * 100
o_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t            0.009034     0.0   0.018068        0.0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                      0.0     0.0        0.0        0.0
#
#                           organization_s  person_s political_organization_s  \
# company_t                       0.000000       NaN                      NaN
# event_t                         0.000000       NaN                      NaN
# location_t                      0.000000       NaN                      NaN
# movement_t                      0.009034       NaN                      NaN
# organization_t                  0.054205  0.027103                 0.009034
# person_t                        0.036137       NaN                      NaN
# political_organization_t        0.000000       NaN                      NaN
# vessel_t                        0.009034       NaN                      NaN
# unknown_t                       0.045171       0.0                      0.0
#
#                           vessel_s  unknown_s
# company_t                      NaN   0.000000
# event_t                        NaN   0.000000
# location_t                     NaN   0.000000
# movement_t                     NaN   0.000000
# organization_t            0.009034   0.018068
# person_t                       NaN   0.009034
# political_organization_t       NaN   0.000000
# vessel_t                       NaN   0.000000
# unknown_t                      0.0   0.000000

# %% [markdown]
# # Partnership

# %%
arr3 = np.zeros((9,9))

p_table=pd.DataFrame(arr3, columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])

p_table_4points=pd.DataFrame( columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])
p_table_4points['organization_s'] = 0
p_table_4points['unknown_s'] = 0
p_table_4points.iloc[4] = 0
p_table_4points.iloc[8] = 0

p_cnt = 0

# %%
collect_4points = pd.DataFrame()
for row in df.iterrows():
    # print(row[1][1],row[1][7],row[1][9])
    if row[1][1] == 'partnership':
        p_cnt = p_cnt + 1
        p_table[row[1][7]+'_s'][row[1][9]+'_t'] = p_table[row[1][7]+'_s'][row[1][9]+'_t'] + 1

        if (row[1][4] == 'Mar de la Vida OJSC') or (row[1][5] == 'Mar de la Vida OJSC') or (row[1][4] == '979893388') or (row[1][5] == '979893388') or (row[1][4] == 'Oceanfront Oasis Inc Carriers') or (row[1][5] == 'Oceanfront Oasis Inc Carriers') or (row[1][4] == '8327') or (row[1][5] == '8327'):
            collect_4points = collect_4points.append(row[1])
            p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1

collect_4points
# Out:
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/2151726921.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = p_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
#        Unnamed: 0    link_type    weight dataset_x  \
# 177           177  partnership  0.855847       MC1
# 777           777  partnership  0.860494       MC1
# 866           866  partnership  0.831708       MC1
# 1095         1095  partnership  0.836273       MC1
# 1142         1142  partnership  0.880474       MC1
# 2414         2414  partnership  0.857494       MC1
# 2422         2422  partnership  0.900931       MC1
# 2594         2594  partnership  0.837715       MC1
# 4533         4533  partnership  0.819067       MC1
# 4961         4961  partnership  0.901047       MC1
# 4966         4966  partnership  0.866931       MC1
# 4967         4967  partnership  0.852776       MC1
# 4968         4968  partnership  0.854423       MC1
# 4970         4970  partnership  0.838082       MC1
# 4974         4974  partnership  0.831604       MC1
# 4982         4982  partnership  0.816541       MC1
# 4983         4983  partnership  0.827533       MC1
# 4984         4984  partnership  0.856693       MC1
# 4985         4985  partnership  0.864877       MC1
# 4986         4986  partnership  0.833301       MC1
# 4987         4987  partnership  0.810879       MC1
# 4988         4988  partnership  0.928481       MC1
# 4989         4989  partnership  0.855360       MC1
# 4990         4990  partnership  0.899304       MC1
# 4991         4991  partnership  0.945531       MC1
# 4992         4992  partnership  0.822198       MC1
# 4993         4993  partnership  0.933341       MC1
# 4994         4994  partnership  0.969303       MC1
# 4995         4995  partnership  0.867280       MC1
# 4996         4996  partnership  0.909865       MC1
# 4997         4997  partnership  0.901353       MC1
# 5005         5005  partnership  0.937897       MC1
# 5006         5006  partnership  0.959120       MC1
# 5007         5007  partnership  0.908736       MC1
# 5008         5008  partnership  0.935585       MC1
# 5009         5009  partnership  0.886883       MC1
# 5032         5032  partnership  0.801267       MC1
# 5362         5362  partnership  0.834555       MC1
# 6897         6897  partnership  0.866446       MC1
# 7058         7058  partnership  0.841500       MC1
# 7294         7294  partnership  0.957123       MC1
# 7375         7375  partnership  0.851147       MC1
# 8038         8038  partnership  0.812323       MC1
# 8040         8040  partnership  0.802768       MC1
# 8267         8267  partnership  0.896930       MC1
# 8300         8300  partnership  0.900007       MC1
# 8317         8317  partnership  0.881707       MC1
# 8325         8325  partnership  0.868431       MC1
# 10379       10379  partnership  0.909512       MC1
# 10468       10468  partnership  0.884882       MC1
# 10470       10470  partnership  0.882215       MC1
#
#                                              source  \
# 177                      Faroe Islands Shrimp Shark
# 777                                        69150209
# 866                                  Maria Mitchell
# 1095                                           6731
# 1142                                            665
# 2414                                           8327
# 2422                                           8327
# 2594                                           9786
# 4533                                    Kelly Brown
# 4961                                      979893388
# 4966                                      979893388
# 4967                                      979893388
# 4968                                      979893388
# 4970                                      979893388
# 4974                                      979893388
# 4982                                      979893388
# 4983                                      979893388
# 4984                                      979893388
# 4985                                      979893388
# 4986                                      979893388
# 4987                                      979893388
# 4988                                      979893388
# 4989                                      979893388
# 4990                                      979893388
# 4991                                      979893388
# 4992                                      979893388
# 4993                                      979893388
# 4994                                      979893388
# 4995                                      979893388
# 4996                                      979893388
# 4997                                      979893388
# 5005                                      979893388
# 5006                                      979893388
# 5007                                      979893388
# 5008                                      979893388
# 5009                                      979893388
# 5032                                      979893388
# 5362                                        6335187
# 6897                                       58877070
# 7058                                     Lisa Rocha
# 7294           6f59e8d7-8f5d-4a7d-a3a4-50ddcb7ad9ad
# 7375                                         542341
# 8038                                  Kevin Burnett
# 8040           decfc924-5bdc-4fba-8bbd-bb57d8d478d9
# 8267                                        6070651
# 8300           c01c6a10-60c9-4f11-9409-aa04c3963826
# 8317                                            156
# 8325           1eb512b7-c4ce-4b7e-9965-2236bf1afc9e
# 10379  Estrella de Coral Ltd. Corporation Logistics
# 10468                           Mar de la Vida OJSC
# 10470                           Mar de la Vida OJSC
#
#                                      target  key             source_type  \
# 177                               979893388    0                 company
# 777                               979893388    0            organization
# 866                               979893388    0                  person
# 1095                              979893388    0            organization
# 1142                              979893388    0            organization
# 2414                                 185106    0            organization
# 2422                           Calvin Salas    0            organization
# 2594                              979893388    0            organization
# 4533                              979893388    0                  person
# 4961                                 months    0            organization
# 4966                                  98703    0            organization
# 4967                           Dana Goodwin    0            organization
# 4968                                    567    0            organization
# 4970                                     23    0            organization
# 4974            ARA Contraalmirante Cordero    0            organization
# 4982                                 418382    0            organization
# 4983                               16927047    0            organization
# 4984                                  30041    0            organization
# 4985                                6471708    0            organization
# 4986                                 520673    0            organization
# 4987                                 565431    0            organization
# 4988               Benton Ltd. Liability Co    0            organization
# 4989                                 ninety    0            organization
# 4990                                  dup90    0            organization
# 4991                                   days    0            organization
# 4992                    sh rn y Corporation    0            organization
# 4993                              822596165    0            organization
# 4994                                   5421    0            organization
# 4995                                   2913    0            organization
# 4996                Pez Dorado BV Logistics    0            organization
# 4997   019d89a8-36be-4402-bf3c-d13cb982cf3f    0            organization
# 5005                                     57    0            organization
# 5006                             Luis Jones    0            organization
# 5007   c01c6a10-60c9-4f11-9409-aa04c3963826    0            organization
# 5008                                  17232    0            organization
# 5009                            Derek Burke    0            organization
# 5032                         20370602035941    0            organization
# 5362                              979893388    0            organization
# 6897                              979893388    0            organization
# 7058                              979893388    0                  person
# 7294                              979893388    0                location
# 7375                              979893388    0            organization
# 8038                    Mar de la Vida OJSC    0                  person
# 8040                    Mar de la Vida OJSC    0                location
# 8267                              979893388    0            organization
# 8300                              979893388    0                location
# 8317                              979893388    0  political_organization
# 8325                              979893388    0                location
# 10379                             979893388    0                 unknown
# 10468                         Kevin Burnett    0                 unknown
# 10470                        Rebecca Walker    0                 unknown
#
#        source_country             target_type  target_country
# 177          Rio Isla            organization             NaN
# 777               NaN            organization             NaN
# 866           Oceanus            organization             NaN
# 1095              NaN            organization             NaN
# 1142              NaN            organization             NaN
# 2414              NaN            organization             NaN
# 2422              NaN                  person         Marebak
# 2594              NaN            organization             NaN
# 4533   Country_198078            organization             NaN
# 4961              NaN                movement             NaN
# 4966              NaN            organization             NaN
# 4967              NaN                  person         Marebak
# 4968              NaN            organization             NaN
# 4970              NaN            organization             NaN
# 4974              NaN                  vessel             NaN
# 4982              NaN            organization             NaN
# 4983              NaN            organization             NaN
# 4984              NaN            organization             NaN
# 4985              NaN            organization             NaN
# 4986              NaN            organization             NaN
# 4987              NaN            organization             NaN
# 4988              NaN                 company  Country_271835
# 4989              NaN                movement             NaN
# 4990              NaN                   event             NaN
# 4991              NaN                movement             NaN
# 4992              NaN                 unknown             NaN
# 4993              NaN            organization             NaN
# 4994              NaN            organization             NaN
# 4995              NaN            organization             NaN
# 4996              NaN                 company  Country_271835
# 4997              NaN                location             NaN
# 5005              NaN  political_organization             NaN
# 5006              NaN                  person       Riodelsol
# 5007              NaN                location             NaN
# 5008              NaN  political_organization             NaN
# 5009              NaN                  person        Nalakond
# 5032              NaN                 unknown             NaN
# 5362              NaN            organization             NaN
# 6897              NaN            organization             NaN
# 7058        Quandarix            organization             NaN
# 7294              NaN            organization             NaN
# 7375              NaN            organization             NaN
# 8038   Country_271835                 unknown             NaN
# 8040              NaN                 unknown             NaN
# 8267              NaN            organization             NaN
# 8300              NaN            organization             NaN
# 8317              NaN            organization             NaN
# 8325              NaN            organization             NaN
# 10379             NaN            organization             NaN
# 10468             NaN                  person  Country_271835
# 10470             NaN                  person  Country_271835

# %%
# 个数
p_table
# Out:
#                           company_s  event_s  location_s  movement_s  \
# company_t                      11.0      2.0        14.0         2.0
# event_t                         5.0      4.0        10.0         1.0
# location_t                     10.0      0.0        17.0         2.0
# movement_t                      6.0      1.0         6.0         3.0
# organization_t                 74.0      4.0        58.0         1.0
# person_t                       40.0      8.0        68.0         4.0
# political_organization_t        2.0      1.0        14.0         0.0
# vessel_t                        2.0      1.0         5.0         0.0
# unknown_t                      43.0      9.0        42.0         4.0
#
#                           organization_s  person_s  political_organization_s  \
# company_t                           68.0      30.0                       3.0
# event_t                             22.0      33.0                       2.0
# location_t                          49.0      28.0                      12.0
# movement_t                          10.0       2.0                       0.0
# organization_t                     459.0     121.0                      31.0
# person_t                           182.0       0.0                      19.0
# political_organization_t            41.0      25.0                       8.0
# vessel_t                            25.0      10.0                       0.0
# unknown_t                          123.0      91.0                      10.0
#
#                           vessel_s  unknown_s
# company_t                      4.0       24.0
# event_t                        0.0        5.0
# location_t                     8.0       18.0
# movement_t                     0.0        1.0
# organization_t                11.0      112.0
# person_t                      14.0      109.0
# political_organization_t       1.0        7.0
# vessel_t                      10.0        9.0
# unknown_t                     13.0      693.0

# %%
# 个数
p_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t                   1       0          3          0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                        0       0          1          0
#
#                           organization_s person_s political_organization_s  \
# company_t                              2      NaN                      NaN
# event_t                                1      NaN                      NaN
# location_t                             2      NaN                      NaN
# movement_t                             3      NaN                      NaN
# organization_t                        21        3                        1
# person_t                               4      NaN                      NaN
# political_organization_t               2      NaN                      NaN
# vessel_t                               1      NaN                      NaN
# unknown_t                              2        1                        0
#
#                          vessel_s  unknown_s
# company_t                     NaN          0
# event_t                       NaN          0
# location_t                    NaN          0
# movement_t                    NaN          0
# organization_t                  0          1
# person_t                      NaN          2
# political_organization_t      NaN          0
# vessel_t                      NaN          0
# unknown_t                       0          0

# %%
# 总数
print(p_cnt)
# Out:
# 2917

# %%
# 比例
p_table=(p_table/11069) * 100
p_table
# Out:
#                           company_s   event_s  location_s  movement_s  \
# company_t                  0.099377  0.018068    0.126479    0.018068
# event_t                    0.045171  0.036137    0.090342    0.009034
# location_t                 0.090342  0.000000    0.153582    0.018068
# movement_t                 0.054205  0.009034    0.054205    0.027103
# organization_t             0.668534  0.036137    0.523986    0.009034
# person_t                   0.361370  0.072274    0.614328    0.036137
# political_organization_t   0.018068  0.009034    0.126479    0.000000
# vessel_t                   0.018068  0.009034    0.045171    0.000000
# unknown_t                  0.388472  0.081308    0.379438    0.036137
#
#                           organization_s  person_s  political_organization_s  \
# company_t                       0.614328  0.271027                  0.027103
# event_t                         0.198753  0.298130                  0.018068
# location_t                      0.442678  0.252959                  0.108411
# movement_t                      0.090342  0.018068                  0.000000
# organization_t                  4.146716  1.093143                  0.280061
# person_t                        1.644232  0.000000                  0.171651
# political_organization_t        0.370404  0.225856                  0.072274
# vessel_t                        0.225856  0.090342                  0.000000
# unknown_t                       1.111211  0.822116                  0.090342
#
#                           vessel_s  unknown_s
# company_t                 0.036137   0.216822
# event_t                   0.000000   0.045171
# location_t                0.072274   0.162616
# movement_t                0.000000   0.009034
# organization_t            0.099377   1.011835
# person_t                  0.126479   0.984732
# political_organization_t  0.009034   0.063240
# vessel_t                  0.090342   0.081308
# unknown_t                 0.117445   6.260728

# %%
# 比例
p_table_4points=(p_table_4points/11069) * 100
p_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t            0.009034     0.0   0.027103        0.0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                      0.0     0.0   0.009034        0.0
#
#                           organization_s  person_s political_organization_s  \
# company_t                       0.018068       NaN                      NaN
# event_t                         0.009034       NaN                      NaN
# location_t                      0.018068       NaN                      NaN
# movement_t                      0.027103       NaN                      NaN
# organization_t                  0.189719  0.027103                 0.009034
# person_t                        0.036137       NaN                      NaN
# political_organization_t        0.018068       NaN                      NaN
# vessel_t                        0.009034       NaN                      NaN
# unknown_t                       0.018068  0.009034                      0.0
#
#                          vessel_s  unknown_s
# company_t                     NaN   0.000000
# event_t                       NaN   0.000000
# location_t                    NaN   0.000000
# movement_t                    NaN   0.000000
# organization_t                0.0   0.009034
# person_t                      NaN   0.018068
# political_organization_t      NaN   0.000000
# vessel_t                      NaN   0.000000
# unknown_t                     0.0   0.000000

# %% [markdown]
# # Membership

# %%
arr5 = np.zeros((9,9))

m_table=pd.DataFrame(arr5, columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])

m_table_4points=pd.DataFrame( columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])

m_table_4points['organization_s'] = 0
m_table_4points['unknown_s'] = 0
m_table_4points.iloc[4] = 0
m_table_4points.iloc[8] = 0

m_cnt = 0

# %%
collect_4points = pd.DataFrame()
for row in df.iterrows():
    # print(row[1][1],row[1][7],row[1][9])
    if row[1][1] == 'membership':
        m_cnt = m_cnt + 1
        m_table[row[1][7]+'_s'][row[1][9]+'_t'] = m_table[row[1][7]+'_s'][row[1][9]+'_t'] + 1

        if (row[1][4] == 'Mar de la Vida OJSC') or (row[1][5] == 'Mar de la Vida OJSC') or (row[1][4] == '979893388') or (row[1][5] == '979893388') or (row[1][4] == 'Oceanfront Oasis Inc Carriers') or (row[1][5] == 'Oceanfront Oasis Inc Carriers') or (row[1][4] == '8327') or (row[1][5] == '8327'):
            collect_4points = collect_4points.append(row[1])
            m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1

collect_4points
# Out:
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/739606551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = m_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
#        Unnamed: 0   link_type    weight dataset_x                  source  \
# 1249         1249  membership  0.901995       MC1               435054320
# 1693         1693  membership  0.854808       MC1            png xi  Line
# 1954         1954  membership  0.826960       MC1                   April
# 1991         1991  membership  0.803921       MC1        Jennifer Alvarez
# 2114         2114  membership  0.806434       MC1        Stephanie Hinton
# ...           ...         ...       ...       ...                     ...
# 10476       10476  membership  0.910024       MC1     Mar de la Vida OJSC
# 10477       10477  membership  0.936195       MC1     Mar de la Vida OJSC
# 10479       10479  membership  0.933502       MC1     Mar de la Vida OJSC
# 10736       10736  membership  0.885812       MC1  Forwading S.A. de C.V.
# 10878       10878  membership  0.898833       MC1                   âUS
#
#                              target  key   source_type  source_country  \
# 1249                           8327    0  organization             NaN
# 1693                      979893388    0       company  Country_628643
# 1954                      979893388    0         event             NaN
# 1991                      979893388    0        person         Oceanus
# 2114                      979893388    0        person         Oceanus
# ...                             ...  ...           ...             ...
# 10476                      33681303    0       unknown             NaN
# 10477                         60017    0       unknown             NaN
# 10479  Ancla Azul Company Solutions    0       unknown             NaN
# 10736                     979893388    0       unknown             NaN
# 10878                     979893388    0       unknown             NaN
#
#         target_type target_country
# 1249   organization            NaN
# 1693   organization            NaN
# 1954   organization            NaN
# 1991   organization            NaN
# 2114   organization            NaN
# ...             ...            ...
# 10476  organization            NaN
# 10477  organization            NaN
# 10479       unknown            NaN
# 10736  organization            NaN
# 10878  organization            NaN
#
# [87 rows x 11 columns]

# %%
# 个数
m_table
# Out:
#                           company_s  event_s  location_s  movement_s  \
# company_t                      31.0      6.0        52.0         2.0
# event_t                         8.0      5.0        12.0         4.0
# location_t                     31.0      7.0        61.0         3.0
# movement_t                      5.0      0.0         6.0         0.0
# organization_t                 88.0     17.0       116.0         8.0
# person_t                       65.0     19.0       129.0         5.0
# political_organization_t        3.0      2.0        17.0         0.0
# vessel_t                       16.0      0.0         4.0         1.0
# unknown_t                      83.0     12.0        96.0         4.0
#
#                           organization_s  person_s  political_organization_s  \
# company_t                          104.0      48.0                       9.0
# event_t                             24.0      32.0                       3.0
# location_t                          75.0      55.0                      17.0
# movement_t                           9.0       9.0                       0.0
# organization_t                     408.0     144.0                      55.0
# person_t                           268.0       0.0                      37.0
# political_organization_t            33.0      21.0                      18.0
# vessel_t                            40.0      16.0                       0.0
# unknown_t                          260.0     155.0                      42.0
#
#                           vessel_s  unknown_s
# company_t                      8.0       56.0
# event_t                        0.0       23.0
# location_t                     9.0       56.0
# movement_t                     2.0        5.0
# organization_t                13.0      183.0
# person_t                      20.0      220.0
# political_organization_t       1.0       10.0
# vessel_t                       9.0       17.0
# unknown_t                     12.0      333.0

# %%
# 个数
m_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t                   5       2          2          0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                        0       0          0          0
#
#                           organization_s person_s political_organization_s  \
# company_t                              1      NaN                      NaN
# event_t                                0      NaN                      NaN
# location_t                             1      NaN                      NaN
# movement_t                             0      NaN                      NaN
# organization_t                        22       12                        5
# person_t                              10      NaN                      NaN
# political_organization_t               0      NaN                      NaN
# vessel_t                               1      NaN                      NaN
# unknown_t                              7        0                        1
#
#                          vessel_s  unknown_s
# company_t                     NaN          0
# event_t                       NaN          1
# location_t                    NaN          0
# movement_t                    NaN          0
# organization_t                  0         12
# person_t                      NaN          3
# political_organization_t      NaN          0
# vessel_t                      NaN          0
# unknown_t                       0          2

# %%
# 总数
print(m_cnt)
# Out:
# 3777

# %%
# 比例
m_table=(m_table/11069) * 100
m_table
# Out:
#                           company_s   event_s  location_s  movement_s  \
# company_t                  0.280061  0.054205    0.469780    0.018068
# event_t                    0.072274  0.045171    0.108411    0.036137
# location_t                 0.280061  0.063240    0.551089    0.027103
# movement_t                 0.045171  0.000000    0.054205    0.000000
# organization_t             0.795013  0.153582    1.047972    0.072274
# person_t                   0.587226  0.171651    1.165417    0.045171
# political_organization_t   0.027103  0.018068    0.153582    0.000000
# vessel_t                   0.144548  0.000000    0.036137    0.009034
# unknown_t                  0.749842  0.108411    0.867287    0.036137
#
#                           organization_s  person_s  political_organization_s  \
# company_t                       0.939561  0.433644                  0.081308
# event_t                         0.216822  0.289096                  0.027103
# location_t                      0.677568  0.496883                  0.153582
# movement_t                      0.081308  0.081308                  0.000000
# organization_t                  3.685970  1.300931                  0.496883
# person_t                        2.421176  0.000000                  0.334267
# political_organization_t        0.298130  0.189719                  0.162616
# vessel_t                        0.361370  0.144548                  0.000000
# unknown_t                       2.348902  1.400307                  0.379438
#
#                           vessel_s  unknown_s
# company_t                 0.072274   0.505917
# event_t                   0.000000   0.207788
# location_t                0.081308   0.505917
# movement_t                0.018068   0.045171
# organization_t            0.117445   1.653266
# person_t                  0.180685   1.987533
# political_organization_t  0.009034   0.090342
# vessel_t                  0.081308   0.153582
# unknown_t                 0.108411   3.008402

# %%
# 比例
m_table_4points=(m_table_4points/11069) * 100
m_table_4points
# Out:
#                          company_s   event_s location_s movement_s  \
# company_t                      NaN       NaN        NaN        NaN
# event_t                        NaN       NaN        NaN        NaN
# location_t                     NaN       NaN        NaN        NaN
# movement_t                     NaN       NaN        NaN        NaN
# organization_t            0.045171  0.018068   0.018068        0.0
# person_t                       NaN       NaN        NaN        NaN
# political_organization_t       NaN       NaN        NaN        NaN
# vessel_t                       NaN       NaN        NaN        NaN
# unknown_t                      0.0       0.0        0.0        0.0
#
#                           organization_s  person_s political_organization_s  \
# company_t                       0.009034       NaN                      NaN
# event_t                         0.000000       NaN                      NaN
# location_t                      0.009034       NaN                      NaN
# movement_t                      0.000000       NaN                      NaN
# organization_t                  0.198753  0.108411                 0.045171
# person_t                        0.090342       NaN                      NaN
# political_organization_t        0.000000       NaN                      NaN
# vessel_t                        0.009034       NaN                      NaN
# unknown_t                       0.063240       0.0                 0.009034
#
#                          vessel_s  unknown_s
# company_t                     NaN   0.000000
# event_t                       NaN   0.009034
# location_t                    NaN   0.000000
# movement_t                    NaN   0.000000
# organization_t                0.0   0.108411
# person_t                      NaN   0.027103
# political_organization_t      NaN   0.000000
# vessel_t                      NaN   0.000000
# unknown_t                     0.0   0.018068

# %% [markdown]
# # Family_relationship

# %%
arr7 = np.zeros((9,9))

f_table=pd.DataFrame(arr7, columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])

f_table_4points=pd.DataFrame(columns=['company_s', 'event_s', 'location_s', 'movement_s', 'organization_s', 'person_s', 'political_organization_s', 'vessel_s', 'unknown_s'],index=['company_t', 'event_t', 'location_t', 'movement_t', 'organization_t', 'person_t', 'political_organization_t', 'vessel_t', 'unknown_t'])
f_table_4points['organization_s'] = 0
f_table_4points['unknown_s'] = 0
f_table_4points.iloc[4] = 0
f_table_4points.iloc[8] = 0

f_cnt = 0

# %%
collect_4points = pd.DataFrame()
for row in df.iterrows():
    # print(row[1][1],row[1][7],row[1][9])
    if row[1][1] == 'family_relationship':
        f_cnt = f_cnt + 1
        f_table[row[1][7]+'_s'][row[1][9]+'_t'] = f_table[row[1][7]+'_s'][row[1][9]+'_t'] + 1

        if (row[1][4] == 'Mar de la Vida OJSC') or (row[1][5] == 'Mar de la Vida OJSC') or (row[1][4] == '979893388') or (row[1][5] == '979893388') or (row[1][4] == 'Oceanfront Oasis Inc Carriers') or (row[1][5] == 'Oceanfront Oasis Inc Carriers') or (row[1][4] == '8327') or (row[1][5] == '8327'):
            collect_4points = collect_4points.append(row[1])
            f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1

collect_4points
# Out:
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   collect_4points = collect_4points.append(row[1])
# /var/folders/rw/kvt1fn_n0h951yj9_wjsc5wm0000gn/T/ipykernel_60729/1248081312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] = f_table_4points[row[1][7]+'_s'][row[1][9]+'_t'] + 1
#        Unnamed: 0            link_type    weight dataset_x  \
# 437           437  family_relationship  0.863973       MC1
# 471           471  family_relationship  0.856004       MC1
# 582           582  family_relationship  0.870096       MC1
# 601           601  family_relationship  0.847895       MC1
# 602           602  family_relationship  0.858981       MC1
# ...           ...                  ...       ...       ...
# 10497       10497  family_relationship  0.883705       MC1
# 10513       10513  family_relationship  0.831505       MC1
# 10587       10587  family_relationship  0.868569       MC1
# 10946       10946  family_relationship  0.830367       MC1
# 10977       10977  family_relationship  0.904092       MC1
#
#                                 source     target  key   source_type  \
# 437                                  4  979893388    0  organization
# 471                             196159  979893388    0  organization
# 582                               9067  979893388    0  organization
# 601                             750975  979893388    0  organization
# 602                             750975  979893388    1  organization
# ...                                ...        ...  ...           ...
# 10497                          Seafood  979893388    0       unknown
# 10513                        Caribbean  979893388    0       unknown
# 10587                    âCompliance  979893388    0       unknown
# 10946  Lake Tanganyika Sea AS Shipping  979893388    0       unknown
# 10977                               MV  979893388    0       unknown
#
#       source_country   target_type target_country
# 437              NaN  organization            NaN
# 471              NaN  organization            NaN
# 582              NaN  organization            NaN
# 601              NaN  organization            NaN
# 602              NaN  organization            NaN
# ...              ...           ...            ...
# 10497            NaN  organization            NaN
# 10513            NaN  organization            NaN
# 10587            NaN  organization            NaN
# 10946            NaN  organization            NaN
# 10977            NaN  organization            NaN
#
# [74 rows x 11 columns]

# %%
# 个数
f_table
# Out:
#                           company_s  event_s  location_s  movement_s  \
# company_t                      12.0      1.0        14.0         1.0
# event_t                         1.0      0.0         1.0         1.0
# location_t                     20.0      2.0        18.0         2.0
# movement_t                      1.0      0.0         3.0         0.0
# organization_t                 50.0      6.0        47.0         1.0
# person_t                       23.0      4.0        31.0         5.0
# political_organization_t        2.0      0.0         5.0         0.0
# vessel_t                        4.0      0.0         9.0         0.0
# unknown_t                      33.0      4.0        26.0         1.0
#
#                           organization_s  person_s  political_organization_s  \
# company_t                           78.0      22.0                       3.0
# event_t                              9.0       7.0                       1.0
# location_t                          61.0      13.0                       6.0
# movement_t                           4.0       2.0                       0.0
# organization_t                     211.0      46.0                      20.0
# person_t                            98.0     920.0                      12.0
# political_organization_t            16.0       3.0                       2.0
# vessel_t                            13.0       8.0                       0.0
# unknown_t                           87.0      31.0                      10.0
#
#                           vessel_s  unknown_s
# company_t                      2.0       31.0
# event_t                        0.0        1.0
# location_t                     4.0       29.0
# movement_t                     1.0        4.0
# organization_t                 6.0       66.0
# person_t                      10.0       58.0
# political_organization_t       0.0        7.0
# vessel_t                       3.0        3.0
# unknown_t                      3.0      156.0

# %%
# 个数
f_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t                   1       0          7          0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                        0       0          0          0
#
#                           organization_s person_s political_organization_s  \
# company_t                              5      NaN                      NaN
# event_t                                0      NaN                      NaN
# location_t                             0      NaN                      NaN
# movement_t                             0      NaN                      NaN
# organization_t                        22        9                        1
# person_t                               7      NaN                      NaN
# political_organization_t               0      NaN                      NaN
# vessel_t                               0      NaN                      NaN
# unknown_t                             10        0                        0
#
#                          vessel_s  unknown_s
# company_t                     NaN          0
# event_t                       NaN          0
# location_t                    NaN          1
# movement_t                    NaN          0
# organization_t                  0         10
# person_t                      NaN          0
# political_organization_t      NaN          0
# vessel_t                      NaN          0
# unknown_t                       0          1

# %%
# 总数
print(f_cnt)
# Out:
# 2395

# %%
# 比例
f_table=(f_table/11069) * 100
f_table
# Out:
#                           company_s   event_s  location_s  movement_s  \
# company_t                  0.108411  0.009034    0.126479    0.009034
# event_t                    0.009034  0.000000    0.009034    0.009034
# location_t                 0.180685  0.018068    0.162616    0.018068
# movement_t                 0.009034  0.000000    0.027103    0.000000
# organization_t             0.451712  0.054205    0.424609    0.009034
# person_t                   0.207788  0.036137    0.280061    0.045171
# political_organization_t   0.018068  0.000000    0.045171    0.000000
# vessel_t                   0.036137  0.000000    0.081308    0.000000
# unknown_t                  0.298130  0.036137    0.234890    0.009034
#
#                           organization_s  person_s  political_organization_s  \
# company_t                       0.704671  0.198753                  0.027103
# event_t                         0.081308  0.063240                  0.009034
# location_t                      0.551089  0.117445                  0.054205
# movement_t                      0.036137  0.018068                  0.000000
# organization_t                  1.906225  0.415575                  0.180685
# person_t                        0.885355  8.311501                  0.108411
# political_organization_t        0.144548  0.027103                  0.018068
# vessel_t                        0.117445  0.072274                  0.000000
# unknown_t                       0.785979  0.280061                  0.090342
#
#                           vessel_s  unknown_s
# company_t                 0.018068   0.280061
# event_t                   0.000000   0.009034
# location_t                0.036137   0.261993
# movement_t                0.009034   0.036137
# organization_t            0.054205   0.596260
# person_t                  0.090342   0.523986
# political_organization_t  0.000000   0.063240
# vessel_t                  0.027103   0.027103
# unknown_t                 0.027103   1.409341

# %%
# 比例
f_table_4points=(f_table_4points/11069) * 100
f_table_4points
# Out:
#                          company_s event_s location_s movement_s  \
# company_t                      NaN     NaN        NaN        NaN
# event_t                        NaN     NaN        NaN        NaN
# location_t                     NaN     NaN        NaN        NaN
# movement_t                     NaN     NaN        NaN        NaN
# organization_t            0.009034     0.0    0.06324        0.0
# person_t                       NaN     NaN        NaN        NaN
# political_organization_t       NaN     NaN        NaN        NaN
# vessel_t                       NaN     NaN        NaN        NaN
# unknown_t                      0.0     0.0        0.0        0.0
#
#                           organization_s  person_s political_organization_s  \
# company_t                       0.045171       NaN                      NaN
# event_t                         0.000000       NaN                      NaN
# location_t                      0.000000       NaN                      NaN
# movement_t                      0.000000       NaN                      NaN
# organization_t                  0.198753  0.081308                 0.009034
# person_t                        0.063240       NaN                      NaN
# political_organization_t        0.000000       NaN                      NaN
# vessel_t                        0.000000       NaN                      NaN
# unknown_t                       0.090342       0.0                      0.0
#
#                          vessel_s  unknown_s
# company_t                     NaN   0.000000
# event_t                       NaN   0.000000
# location_t                    NaN   0.009034
# movement_t                    NaN   0.000000
# organization_t                0.0   0.090342
# person_t                      NaN   0.000000
# political_organization_t      NaN   0.000000
# vessel_t                      NaN   0.000000
# unknown_t                     0.0   0.009034
