# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### 最大的弱连通分量拿出来

# %%
# 读取weakly connected component.json
with open('weakly connected component.json', "r", encoding='utf-8') as r:
    wcc = json.loads(r.read())
wcc=np.array(wcc)
wcc.squeeze()
wcc.shape
# Out:
# (83,)

# %%
biggest_wcc=wcc[0]
biggest_wcc_com=biggest_wcc['component']
biggest_wcc_com
# Out:
# ['812137',
#  '2ade0908-d1c9-45de-9dbb-3dfec75d9317',
#  '33560',
#  '56126935',
#  'Timothy Hampton',
#  'Denise Vance',
#  '5337',
#  'Chad Nichols',
#  '9ce492a2-de6e-4231-a018-318fc929908b',
#  'Stacy Castillo',
#  '63',
#  'Blake Smith',
#  '672',
#  'Rhonda Johnson',
#  '80774',
#  'Leominster Provincetownâ',
#  'Dawn Robinson',
#  '2983',
#  '1334578',
#  'Andrea White',
#  'Wendy Miller',
#  '649009867',
#  '26676370',
#  'Brandon Berger',
#  'Fisheries Animal Industriesâ',
#  '76609426',
#  'e2816018-e01c-4eac-8dc5-e84aebc22cff',
#  '245658',
#  '1f8c20da-5f20-4116-907a-a653089bb8a0',
#  'Alyssa Gonzalez',
#  'Jacob Caldwell',
#  'David Mcfarland',
#  'Ocean Packers',
#  'c0ce6d15-622b-42a3-b892-f5efe5b4d00c',
#  'Lindsey Conway',
#  'Seaside Sojourns A/S Shipping',
#  '262157542',
#  '28890617',
#  '72092',
#  'â\x80\x9cillegalâ',
#  '176',
#  'ab195b55-453e-4436-ab0c-9f5660b4ec8c',
#  'Jason Hughes',
#  'Joshua Park',
#  '67a59fab-710a-4992-b6d0-d581fd9dceba',
#  '90be60b1-61d8-4115-b133-e4c8e09383eb',
#  'Michelle Aguilar',
#  'Patricia Byrd',
#  '567217',
#  '218',
#  'Justin Fowler',
#  'b5856109-c5a0-43a6-8c70-ebfe73cc24f1',
#  '5276019',
#  'Jamie Robinson',
#  'Vessels',
#  'Kristin Davidson',
#  'Brian Hansen',
#  'Tammy Ryan',
#  'th',
#  '6185842',
#  '114d2882-b620-4098-bb56-d865bbb85339',
#  'Fishing International',
#  'Amphibious Warships',
#  'Coral Reef Sagl Transport',
#  'c40a73e5-c1dd-4b85-ac1c-2e6a51546aa7',
#  '63548588',
#  'Amanda Scott',
#  'STL',
#  'Kathy Rodriguez',
#  '7480',
#  '1360',
#  'cd7cb49f-0021-4fe9-a3a9-cc8b3fce0c57',
#  'b4caf8cd-dbc7-4c99-9f2b-de407274c08b',
#  'Jerry Montgomery',
#  'HMAS',
#  '492238508',
#  '382825160',
#  '813be272-d3de-43c9-90be-ab14231fcf17',
#  'Madhya Pradesh Market BV',
#  'cf651b3c-4e21-458c-91c4-3cae2eb36bcb',
#  'April James',
#  'Brian Wolfe',
#  '98703',
#  'William Palmer',
#  '565431',
#  '48115',
#  'Bryan Taylor',
#  'Mary Castillo',
#  'Henry Lambert',
#  'Caracola Azul Limited Liability Company',
#  'Susan Williams',
#  'Andrew Harrison',
#  'The Salty Dog CJSC',
#  '9590898',
#  '7914',
#  '842229565',
#  'EBSCOhostâ\x80\x94searched â\x80\x98octopus',
#  '9768',
#  'Benton Ltd. Liability Co',
#  'â\x80\x98womenâ',
#  '60-day',
#  'Ocean Tuna',
#  '662bfccd-798d-4e60-b308-2cb2918e3dd2',
#  'Brandon Stone',
#  'f514483d-fb5f-4cb2-bb8d-b616b10336d8',
#  'The Salty Dog Tidepool Kga Transport',
#  '454',
#  'James Patterson',
#  'fc4e853f-6e18-4631-bf95-f70d6a30579f',
#  '8541598',
#  '34757443',
#  '9697',
#  '4524860',
#  'Suzanne Reed',
#  'Luis Douglas',
#  'Dawn Sanchez',
#  '22',
#  'l y S.A. de C.V. International',
#  '637',
#  '86117',
#  'Paul Wiley',
#  'png xi  Line',
#  'Fresh On Time Seafood',
#  '962534403',
#  'Niger River Delta Ges.m.b.H. Services',
#  'Rapido beam trawler',
#  'David Nielsen',
#  'Talleyâ\x80\x99s',
#  '1225',
#  'abcb0d9c-80da-4491-99f3-e093984f5373',
#  'Estrella del Sol LLC',
#  '42258',
#  '49494',
#  '90831',
#  '679399',
#  'â\x80\x9cpioneersâ',
#  'W&O Supply',
#  'James Smith MD',
#  '911',
#  'Joshua Huang',
#  'Bruce Spears',
#  'Gabriela Graham',
#  'Terry Murphy',
#  'Elizabeth Savage',
#  '78135',
#  'Emily Kennedy',
#  '353257',
#  'Deborah Carson',
#  'cc6cf3e0-5794-4497-a31d-79b4db1b55a9',
#  'Nathaniel Shah',
#  'heâ\x80\x99s',
#  'Seabreeze Foods Corporation Logistics',
#  'Zachary Jordan',
#  'Susan Williamson',
#  'd2948905-9121-400b-905f-e449bf8ca35e',
#  'Thomas Morales',
#  'Adam Blankenship',
#  'Julie Callahan',
#  'dup18',
#  '1560',
#  '96',
#  'Brandi Bowen',
#  '4356',
#  'MV',
#  'Ancla del Mar Ltd. Corporation',
#  'GalÃ',
#  '39893',
#  'Ricardo Gomez',
#  'Fridayâ\x80\x99s',
#  '8513',
#  '3015',
#  'DiÃ',
#  '740111283',
#  'Nile Crocodile Deep-sea Oyj Brothers',
#  '683113035',
#  'Leslie Williams',
#  '51',
#  'Margaret Hodges',
#  'Alan Pacheco',
#  '12',
#  'Playa del Mar Caviar',
#  'Playa de la Luna Ltd. Corporation',
#  'Coast Guard Cutter Edgar Culbertson',
#  'Cape of Good Hope  Oyj',
#  '6ead18ca-3084-4f8e-9c1e-a5e470fc5935',
#  'Storm',
#  'Prod',
#  '14 months',
#  'Alicia Lee',
#  '70720996',
#  'Robert Schaefer',
#  'William Gray',
#  '7775',
#  '402',
#  '199',
#  'Chad Ruiz',
#  'Stephanie Robinson',
#  'Kevin Butler',
#  '15785056',
#  'â\x80\x9cHelpâ',
#  'Jeff Sullivan',
#  'Austin Simpson',
#  'Intrepid Navigators',
#  'McGovern BBB',
#  '207618139',
#  'AND fisheryâ',
#  '4',
#  'â\x80\x98Do',
#  'Jennifer Price',
#  'Matthew White',
#  '71835024',
#  '35',
#  'scaleâ',
#  'Tshikele Ltd. Liability Co',
#  '7321',
#  'James Valencia',
#  '89526932',
#  '71608',
#  'Calvin Salas',
#  '595038316',
#  '26794528-86a5-4b5e-802f-50c3f226c66b',
#  'Tyler Guzman',
#  'Melinda Wade',
#  '45361487',
#  '372016989',
#  '8698',
#  'Dolphin Dreams S.A. de C.V. Seafood',
#  'Randy Collins',
#  '947',
#  'Mongabayâ\x80\x99s',
#  'Ryabikova',
#  'Craig Santiago',
#  '54726',
#  '959344',
#  'United Statesâ',
#  '23636990',
#  '83951569',
#  '1dfb2440-85dc-4f0c-914f-e18498e6cd1b',
#  'FishEye International',
#  '9507963',
#  'Elizabeth Jones',
#  '685607',
#  '29',
#  'Rodney Compton',
#  'Blue Bay',
#  '414',
#  '0f5fd4f9-1683-464e-9459-a4488de5064b',
#  'Samuel Cross',
#  '5362',
#  'Stephen Gutierrez',
#  'Joshua Garrett',
#  '891',
#  'Virginia Carter',
#  'Mar del Oeste Pic',
#  'Diane Young',
#  '2243528',
#  'Ronald',
#  'â\x80\x9cPortlandâ',
#  'su y CJSC Canal',
#  'Barco de Plata Plc',
#  'David Nunez MD',
#  'Kevin Burnett',
#  'Melissa Norman',
#  'Roger Jordan',
#  'USCGC',
#  'Gregory Marsh',
#  'Heather Porter',
#  'Edward Winters',
#  '405ab2a5-68f0-4304-ab94-24c7995a248e',
#  '34020206',
#  'Jo Francis',
#  '42',
#  'dup96',
#  'Ronnie Gates',
#  '555217629',
#  'Kimberly Lopez',
#  'â\x80\x9cHis',
#  '2679',
#  '23399545',
#  'Daniel Vasquez',
#  '62532',
#  '84616',
#  '7320771',
#  'Amy Wise',
#  'hi xng BV Carriers',
#  '2ef60e7b-4914-4dbd-a063-5b23143fe5db',
#  '431',
#  'â\x80\x9cVirginia',
#  '8561',
#  'Brett Moss',
#  'scooter',
#  '803490608',
#  'Charlotte Lopez',
#  'Zachary Blackburn',
#  'db83c37f-86e4-4694-a81c-ede2a01aef71',
#  'Albert Thomas',
#  'â\x80\x9csatisfactoryâ',
#  '945',
#  '237659945',
#  'c682ec16-cd10-4a6c-94ce-4a5eb590b42e',
#  '657',
#  'Bryan Hill',
#  '2673',
#  'e31b2b9c-3197-4c2c-ac40-3c6711a4682b',
#  'Danielle Sosa',
#  'Maru',
#  'Mitsubishi',
#  'Kari Zavala',
#  '0d1c7ce3-7243-47c0-9280-a3262b52dc0f',
#  '22a2062d-03d8-48c3-9e91-9e5930b8d29f',
#  'FlodstrÃ',
#  'd37a5a00-fca1-4753-890c-6975c311dc3f',
#  'Brittney Rice',
#  '4532329',
#  '4562fe84-0188-47fd-8e27-67380da0079c',
#  'e09b64a2-397a-4bec-96a1-7d61479fe37a',
#  'Belgian Scallop Limited Liability Company Krill',
#  '1518',
#  '45',
#  'Viento y Mar BV',
#  '52093e45-b873-4300-9612-8dfc291b1339',
#  '7413',
#  'Natalie Gill',
#  'Lake Tanganyika Sea AS Shipping',
#  '79',
#  'Todd Lane',
#  'â\x80\x9cinconsistenciesâ',
#  'Rybachit Limited Liability Company',
#  '8732',
#  '801809',
#  '58623386',
#  'f402c1d2-8262-4bae-aa92-c8675a7006fc',
#  '442',
#  'William Bradley',
#  'meridaâ',
#  'Caspian Sea  Sea Corporation Freight ',
#  'Estrella de Mar Ltd. Liability Co',
#  'reefers',
#  'Seth Benjamin',
#  '3190258',
#  '621',
#  '967900443',
#  'Paul Parker',
#  'â\x80\x98greenâ',
#  '111274e2-c155-4640-9a8e-f506f3fbca06',
#  '076',
#  '410af01b-a5fb-4d6c-946d-a48fea30332b',
#  '27641046',
#  'Jessica Brown',
#  '5d1f2e9c-f74a-41e9-974f-9b4e57edc9d7',
#  'Krystal Lee',
#  'c01c6a10-60c9-4f11-9409-aa04c3963826',
#  'Cindy Ritter',
#  '13592',
#  'Victoria Anderson',
#  '440',
#  '75471',
#  'Ntaco',
#  '341',
#  'Alexander Buchanan',
#  'ï¬\x81shes',
#  '7234',
#  '72875',
#  '496391',
#  'ce0d446c-d08d-49a8-8aa2-e625ead63d0c',
#  'd5cbeea1-73ac-4d86-adeb-b609629b12bf',
#  'Firearms Explosives',
#  'e167b40a-96f4-40e0-873b-78950e4434f4',
#  'Kevin Norton',
#  'Holly Taylor',
#  '86ac9e66-f9e8-4f2b-ad17-39a52c23288c',
#  '9357541',
#  'b9faf7c4-f237-4112-91bd-71fa0cf8571a',
#  '05d471b4-0e8c-4879-80b2-ef600220e09d',
#  'Tara Hanson',
#  'Amanda Dean',
#  'a7a35f33-3e72-44f2-a51b-922e44da23bc',
#  'Paul S.A. de C.V.',
#  'Diana Dawson',
#  'Playa del Cielo Kga',
#  'Michael Vazquez',
#  '150486480',
#  '439861274',
#  '109746',
#  '8112222',
#  '724',
#  'Octopus',
#  'XUAR',
#  '653',
#  'Ancla del Mar Kga',
#  '42627990',
#  '96c31987-d50d-4680-9397-2a9d0e3946e1',
#  '65872b93-db53-4445-a72e-8f84b3d7edfc',
#  '55',
#  '23774',
#  'Rama Overseas',
#  '89772543',
#  'Ms. Brittany Murray',
#  '254340176',
#  'Orange River  AS Logistics',
#  '26',
#  '0c0ae060-2543-4d7e-bed0-e7fab24ba6a5',
#  'c66f5cd5-3891-43ce-a3f8-0147b3d643b1',
#  'W Appliance',
#  '950574',
#  'Mark Hernandez PhD',
#  'Emily Bailey',
#  'Lake Malawi SE Freight ',
#  'â\x80\x9ccrisisâ',
#  'Water',
#  'Shawna Welch',
#  'Brian Nelson',
#  'Estrella de Mar Limited Liability Company Delivery',
#  'Playa de Coral Oyj International',
#  'Comei&Co',
#  '8350379',
#  '2573803',
#  'Oceanfront Oasis Inc Carriers',
#  'fisheriesâ',
#  'Tristan Johnson',
#  'Diane Forbes',
#  '2508',
#  'Zachary Perez',
#  '58745',
#  'James Hernandez',
#  '41713',
#  'Danielle Camacho',
#  'James Stewart',
#  '826749274',
#  'Joseph Griffin',
#  '75835980',
#  '1625166',
#  'Kristin Graham',
#  'Food',
#  'Christopher Simon',
#  '493641959',
#  'vesselâ\x80\x99s',
#  '23',
#  'April Perry',
#  '0fab17df-2c08-46b6-8ce9-b13b3a60ff3d',
#  '8153f5cb-e1f7-49bb-91bb-24b3a296a40a',
#  '255â\x80\x93273',
#  '102642',
#  '1bf22b98-519c-4131-8bb4-53ecdd193100',
#  'Alexis Smith',
#  'Matthew Delgado',
#  '87278',
#  '21724',
#  'â\x80\x98Disastrousâ',
#  'Erika Carter',
#  'James Scott',
#  'f2aee915-d483-4823-a030-9aac5e44c1fe',
#  'â\x80\x9ccardingâ',
#  'Scottish Trout Limited Liability Company Transit',
#  'Sabrina Zamora',
#  '8950',
#  '371bf15a-3000-499a-88e4-cc096b028ec7',
#  '95c715ba-891e-4472-8e2a-4e746dcc266a',
#  '404',
#  'Philip Murphy',
#  '0ae94787-4593-4139-848d-9174ea13ac23',
#  '307',
#  '8afc9cb6-edf5-4a7d-9a02-054444a5604e',
#  'Meghan Wolfe',
#  'Olivia Bailey',
#  '8164acdd-514f-4e18-867c-4bc63cebf15b',
#  '47924922',
#  'West Bengal SRL Marine conservation',
#  '2919',
#  'Carrie Elliott',
#  '380',
#  '290834957',
#  'b8649055-5b40-43e1-ba33-93182cf978d4',
#  'Amstel Inc',
#  '4369922c-ce1d-40ff-904c-1f6a3000bf6b',
#  '39995740',
#  '491',
#  'three',
#  '368951',
#  'Anna Johnson',
#  '59',
#  '2230601',
#  'ee077c79-cc7b-4ac7-8c0b-d48f50538f61',
#  'â\x80\x9cPokÃ©mon',
#  '836',
#  '23837996',
#  'Faroe Islands Plc Investment',
#  '576618',
#  '34487',
#  '18403617',
#  'Angela Powers',
#  'e916e286-85e5-4a43-b2ef-89ad5260ebdc',
#  'sectors sectors 2033',
#  'OJSC Ltd. Liability Co',
#  'Coast',
#  'Dry Creek S.p.A. Overseas',
#  '9473',
#  '958085',
#  '2030â',
#  'Tyler Brown',
#  'water fishing',
#  '8851578d-3dd7-4430-8f73-b95305eb1f03',
#  '3896',
#  '39048624',
#  '6b19fec0-f5d4-4d31-b461-fef270debb3e',
#  '2422788',
#  '9098',
#  'Melissa Gonzales',
#  '8787',
#  'Blue Lagoon Sailor Limited Liability Company Worldwide',
#  '14',
#  '21538',
#  'Jennifer Rivera',
#  '97836b65-db6a-43bf-9467-cf57d84645ff',
#  '822596165',
#  '1094345',
#  'Randy Logan',
#  'NiÃ±o',
#  '2ceda972-c633-4a88-bbe8-a4fe48cb5555',
#  'Bethany Lopez',
#  '613465161',
#  'â\x80\x9cDesbloqueio pÃ',
#  'IndÃºstria Madeireira Uliana',
#  'Sudd Swamp  Wave AS Freight ',
#  '802113',
#  '4698',
#  '6083f325-5f17-4d41-9c22-f188f55ea9f3',
#  '2362',
#  '25a765f4-b6d0-4588-9a7a-0798de847cfd',
#  'â\x80\x9cIllegal',
#  '82408558',
#  'Bradley Murphy',
#  '1',
#  'Jessica Figueroa DDS',
#  '43454',
#  'months years',
#  'Cody Baird',
#  '9166',
#  '5421',
#  'Andres Cook',
#  '379284134',
#  'Brett Williams',
#  'Jeffrey Hall',
#  '38',
#  '4946',
#  'Darrell Lopez',
#  'Jeremy Jackson',
#  'Bryan King',
#  'Kristin Jones',
#  'Ships',
#  'Thomas Rivas',
#  '90',
#  'Dana Knapp',
#  '89',
#  '346281879',
#  'Jeanne Mills',
#  'hours',
#  'Lisa Henderson',
#  '86',
#  'Mary Harrington',
#  '903311212',
#  'James Calhoun',
#  'Patrick Cannon',
#  '39c767d3-a9b4-41f4-8a5d-e14b6c20a2d2',
#  '693436',
#  'II',
#  'waterâ\x80\x99s',
#  'Sarah Garcia',
#  'months',
#  '90c3cb48-8060-4a55-804c-710044d19487',
#  '353',
#  '56',
#  'Eva',
#  'dup90',
#  'Melissa Gomez',
#  'Ariel Thornton',
#  'Mary Horton',
#  '185040354',
#  '854',
#  'Marine',
#  'Andrew Graves',
#  'All',
#  '938816',
#  '951187691',
#  '455617',
#  '416dab02-bf67-48af-a99b-c691339dc5e0',
#  '9550',
#  'Sean George',
#  '435978092',
#  'Tonya Key',
#  '762833',
#  'Andrea Hansen',
#  '3782',
#  'Cab Incorportated',
#  '83',
#  '884332',
#  'Lindsay Bennett',
#  'Susan Porter',
#  'da7677f8-d1f0-4e35-afe9-4240613e866b',
#  'Bulk Carrier',
#  'c495290e-2de7-487d-a139-f273c4974539',
#  'Veronica Payne',
#  'a086a63d-19c7-4241-845a-f82c628d09a2',
#  '41398ea8-d14a-4666-80e8-6a212684d871',
#  'cutters',
#  'Lisa Gomez',
#  '9820523',
#  'Michael Alvarez',
#  'ï¬\x81sh',
#  '1303',
#  '428',
#  'Improvised Anti',
#  'Paul Johnson',
#  '49048884',
#  'Pasture Petfoods New Zealand Ltd',
#  'allAfrica',
#  '80',
#  '688224',
#  'Lake Nyasa Ltd. Corporation',
#  'Lauren Reynolds',
#  'Katrina Nguyen',
#  'Melissa Gonzalez',
#  'Veronica Lowe',
#  '265494227',
#  '176729',
#  '7892',
#  '19',
#  'Brian Brown',
#  'a03df7da-c2cf-476d-a6ea-95c422969df2',
#  '604905',
#  '116070050',
#  '81661977',
#  'Deep Sea Atlantic NV',
#  'Jennifer Wilson MD',
#  'Mark Garcia',
#  'a7948099-0cab-4b80-8707-2ada931ac288',
#  'nationalfisherman',
#  'Â£1',
#  '1354',
#  'Chuan gou Company Overseas',
#  'b840c9bf-2a5b-416c-91d9-1ecdd96425ab',
#  '13 yearsâ',
#  'Andrew Miller',
#  'Ashley Johnson',
#  '2278',
#  'Forwading S.A. de C.V.',
#  'Frederick Harris',
#  'Seth Kelley',
#  '7443',
#  '3d009ee1-0d95-4516-802f-8a5110bde01e',
#  'Lisa Lambert',
#  '933c4581-7ecc-4377-995c-7a200fee617b',
#  '95219',
#  '1263250',
#  'Erin Bowen',
#  '6126134',
#  'Susan Hodges',
#  'Brian Dennis',
#  'â\x80\x9cbe',
#  'Insung',
#  'Melissa Bates',
#  '511915273',
#  'DDG',
#  '9699687',
#  '36b70b18-465a-442f-bfbe-cedb85d48acc',
#  'Mexicoâ\x80\x99â',
#  'Janice Bell',
#  '36744944',
#  'Plattsâ',
#  '495035052',
#  '6ffd3349-37f4-48c5-bc9a-1b80e722e939',
#  '78',
#  'Philip Black',
#  'tio MPFâ\x80\x99s Special Action Group Combat Organized Crime',
#  'Ronnie Burns',
#  '3 Ltd. Liability Co',
#  'Okavango Delta Seaside Limited Liability Company Logistics',
#  '890',
#  '4764109',
#  '54056',
#  'f810c631-9f7d-4219-ade0-b44c4c9abf62',
#  'Michelle',
#  'Hardwoodsâ',
#  '498817',
#  '3129',
#  'Robert Vega',
#  'Playa de la Felicidad NV',
#  'Fresh Atlantic',
#  'Ocean Trawlers',
#  '445a6124-4650-4e5a-83bb-a0e0b4040ee9',
#  'Barbara Mccarty',
#  'Debra Hall',
#  'Peter Bush',
#  'Christine Jones',
#  '858773',
#  '95',
#  '8325',
#  '49525439',
#  '3874',
#  '435',
#  'Estrella del Mar Plc',
#  'SIMPComplianceGuide',
#  'David Weber',
#  'â\x80\x9cWhatâ\x80\x99s',
#  '301',
#  '98748',
#  '2eeca6e0-f5a7-4b9d-8b3e-ada56d140e36',
#  '354',
#  '3183',
#  '90411963',
#  'Richard Fleming',
#  '687028',
#  'Costa del Mar Oyj Hijiki',
#  '64545',
#  'Sonia Fisheries Pvt',
#  'â\x80\x9csleepy',
#  'Teion Internationala',
#  'Alyssa Mccoy',
#  'Terry Conley',
#  '80276549',
#  '4942',
#  '144431',
#  '6513816',
#  '858',
#  'c97073d1-61a4-4a06-a189-8b4642a699e1',
#  '5705060',
#  '7845',
#  'Rose',
#  'Master',
#  'Aerial',
#  'Catchâ',
#  '28064',
#  'Melinda Williams',
#  'Danielle Jensen',
#  'Thomas Watkins',
#  'Basketball',
#  'Timothy Austin',
#  '1214936',
#  'James Limited Liability Company Logistics',
#  'Christine Maxwell',
#  '1076f239-831c-4c53-9134-484c8f2d5c73',
#  'Dana Goodwin',
#  'krxd',
#  '3051e013-9e40-44cc-98e5-740e3238daaa',
#  'Jorge Davidson',
#  'oceana',
#  'HMS Medway',
#  'Jasmine Camacho',
#  '5698',
#  'Group Co Marine life',
#  'Kevin Daniel',
#  'Elizabeth Martin',
#  'Jennifer Andrade',
#  '71317',
#  'Brian Marsh',
#  '91',
#  '923825740',
#  '678',
#  '6406040',
#  'â\x80\x9ctigerâ',
#  'â\x82¬7',
#  'Carlos White',
#  'â\x80\x9cnecessaryâ',
#  '7f3d323d-54e3-49f8-9c28-7aa5cb4c7248',
#  'Nagaland Sea Ltd. Liability Co &',
#  'â\x80\x98poulpeâ',
#  'Elaine Duncan',
#  '838200939',
#  'Tyler Palmer',
#  '3878194',
#  'Pez Dorado BV Logistics',
#  'Dean Reyes',
#  '5639000',
#  'Tyler Jones',
#  '14525ad3-213a-406d-8e3e-64213f0be171',
#  'e2844e89-d2d8-428d-8284-a0f2d9450a14',
#  '83818120',
#  'Krystal Foster',
#  '48605',
#  '5235138',
#  '132',
#  '21',
#  'Laura Smith',
#  '22 Raptor',
#  'Laura Williams',
#  'Statesâ',
#  '753589537',
#  'Richard Perkins',
#  'Stephen Evans',
#  'Gina Armstrong DDS',
#  'Faroe Islands Shrimp Shark',
#  'â\x80\x9chigh',
#  'Tammy Martin',
#  'decfc924-5bdc-4fba-8bbd-bb57d8d478d9',
#  'Matthew Martin',
#  'fdcbe098-dbe6-4e52-8bd7-96cf3ae30101',
#  'Feb',
#  '437212',
#  'April',
#  'Willie Hill',
#  'Shipping Corp',
#  '4937447',
#  'Danish Lobster Ltd. Liability Co',
#  'Angela Chang',
#  'Joseph Gonzales',
#  'Barco de Plata Ltd Logistics',
#  'Jason Brown',
#  'Thai Union Seafood',
#  '77b46bc7-7e31-41a0-973c-e633011d21b0',
#  'Khundu Ltd. Liability Co',
#  'f7a4114d-d1ca-44df-a7e0-c72e440671ba',
#  'Kathryn Gomez',
#  'Seafreeze Ltd',
#  'â\x80\x9cVikingâ',
#  '601882545',
#  '0223707c-6754-4419-acb2-510377eadd60',
#  '41',
#  'Electronic',
#  'Robert Carpenter',
#  'Mario Richardson',
#  'Jill Boyd',
#  '2ed68d75-994e-43dd-b326-a2adfa540562',
#  '6f59e8d7-8f5d-4a7d-a3a4-50ddcb7ad9ad',
#  'Mary Clements',
#  'Ht Shipping',
#  'Jessica Hernandez',
#  '71',
#  'Brian Williams',
#  '494197',
#  '5e6b70db-a04a-4440-8991-3a92b5c4ac4d',
#  '5070599',
#  'europeansting',
#  '7298083',
#  '3641',
#  'Petroleum Vapor Intrusion',
#  '21e68e53-183c-45a0-9805-68c099d4d9c0',
#  'drayage companies',
#  '9488645',
#  'Danny Walker',
#  '4962642',
#  'Sierra Smith',
#  '761',
#  '610',
#  'Harold Strickland',
#  '3cda9d0b-77af-4e85-bef8-e935ca55ea06',
#  '79513661-4dbe-4797-a73a-e53177f7a4b3',
#  'French Ltd. Corporation Surfboard',
#  'expect year',
#  'Allison Leonard',
#  'Oceans',
#  'Turkish Mussels Ltd. Liability Co Marine biology',
#  'SMILE',
#  'Thomas Adams',
#  '97453782',
#  '5246016',
#  '3590dd7e-a6cd-416d-9b42-68f692ad83ee',
#  '353149780',
#  'shrimper',
#  '13015105',
#  'Christian Quinn',
#  '85052185',
#  '515270',
#  '88149',
#  'Kristen Martin',
#  '1402',
#  'Ocano del Este Corp Freight ',
#  'Cutters',
#  'FLIP MCGYVER Tradema',
#  '733',
#  'Daniel Henderson',
#  '413760',
#  '410',
#  '7361',
#  'Richard Smith',
#  'Jennifer Alvarez',
#  '47',
#  'Susan Mendoza',
#  '408119',
#  '69007292',
#  'Denise Diaz',
#  'Joanna Brown',
#  'Bryce Chavez',
#  'Jonathan Smith',
#  'â\x80\x9csnitch',
#  'Jennifer Frederick',
#  '59662085',
#  'â\x80\x9cDuare Rationâ',
#  '7a58f899-3e43-4b94-a64b-d5ab31a6055b',
#  'e941d006-6590-4143-9d0d-12926b0b6f5c',
#  '43247945',
#  '4258240',
#  'Ann Nelson',
#  '473c1320-e50b-4f90-a068-76f82e210f26',
#  '1196cfc8-175c-465b-aee9-fbf74c81aa49',
#  'Bonnie Perez',
#  'Playa de Coral GmbH Consultants',
#  'ea6a6547-c93b-4f17-b037-200fa894289c',
#  '762165',
#  'df26d11f-ed87-4a19-b9e8-18e9783c00f5',
#  '48259',
#  '8bdf21e8-914b-4fe2-9280-0a69b9b0175d',
#  '10',
#  '72630',
#  '9636',
#  '663',
#  '228',
#  'Anita Tate',
#  'â\x80\x98Socioeconomic',
#  '486',
#  'f4e17264-3b3c-48a6-86ba-d65622dc2f13',
#  'Remarkable',
#  'Paul Hoover',
#  '68703341',
#  '6043477',
#  'Traci Shields',
#  'Ship2Report',
#  'week',
#  'Dr. Christina Jensen DDS',
#  'Hunt',
#  '7682',
#  '54217974',
#  '54',
#  'â\x80\x9coriginaldragoncoveâ',
#  '418382',
#  'ams.usda',
#  'cb537677-9d82-4d58-8066-899bdc51c4f1',
#  '1a069318-6dc0-45d0-9948-7b846f61c201',
#  '90192265',
#  'Elijah Gordon',
#  'Salles Operation Handroanthus',
#  'Leslie Wood',
#  '449308',
#  'Brandon Jackson',
#  'Isa',
#  'â\x80\x9cbossesâ',
#  '07',
#  'Eugene Martin',
#  '9280',
#  '3731',
#  '285351',
#  '28379',
#  'Mathew Taylor',
#  '2421',
#  '4769248',
#  'Phillips',
#  '8609',
#  'â\x80\x98Perlaâ',
#  'fd6c1e03-d6f4-421e-a493-cdc56ae000b5',
#  'Dylan Roberts',
#  'Brian Palmer',
#  '31',
#  '23777',
#  '59022',
#  '400',
#  'Image ArtTower',
#  '4877',
#  'Manipur Market AG Consultants',
#  '196159',
#  'Linda Sherman',
#  'Kathleen Gates',
#  'Dakota Hansen',
#  '995899',
#  'Jennifer Reilly',
#  'Ocean Fisheries Llc',
#  'Guessl',
#  'a691bc0a-cfdc-4b2a-a38e-efcd2799ecd1',
#  '73921',
#  '280094',
#  'arts',
#  'Daniel Frank',
#  'Selena Building',
#  '303934',
#  '3383',
#  'â\x80\x9ccatch',
#  'â\x80\x9cencounteredâ',
#  'Nathaniel Jimenez',
#  '2032s',
#  '296837',
#  '64863263',
#  '8b8c532f-0ca0-44cc-898c-1d776f2f457a',
#  '74211169',
#  'Kristin Johnston',
#  'Kevin Moreno',
#  '664738735',
#  'e0cdfc51-7473-481d-8900-03f66d6e359e',
#  'Michael Smith',
#  '7674777',
#  '637608',
#  'Jesse Thompson',
#  '214883455',
#  'Scott Medina',
#  '45620',
#  '845',
#  '653505420',
#  'HMS',
#  'Wanda Collins',
#  'Victoria',
#  '9345',
#  'Sharon Townsend',
#  '150674265',
#  ...]

# %%
v1=json.load(open('../../vast_2023_mc1/mc1_vis_system/public/MC1.json'))
merged_info=pd.read_csv('../../vast_2023_mc1/MC1/V1/merged_info.csv')
nodes_df=pd.DataFrame(v1['nodes'])
links_df=pd.DataFrame(v1['links'])

# %%
big_wcc_nodes=nodes_df[nodes_df['id'].isin(biggest_wcc_com)]
big_wcc_nodes
# Out:
#               type dataset   country                        id
# 0          company     MC1  Nalakond  Spanish Shrimp  Carriers
# 1     organization     MC1       NaN                     12744
# 2     organization     MC1       NaN                 143129355
# 3     organization     MC1       NaN                      7775
# 4     organization     MC1       NaN                   1017141
# ...            ...     ...       ...                       ...
# 3422           NaN     MC1       NaN              Felbab-Brown
# 3423           NaN     MC1       NaN            OzonActionâs
# 3424           NaN     MC1       NaN               âEntirely
# 3425           NaN     MC1       NaN         Ocano del Este SE
# 3427           NaN     MC1       NaN      Malabar Sea Catch Sp
#
# [3151 rows x 4 columns]

# %%
big_wcc_links=links_df[(links_df['source'].isin(biggest_wcc_com)) & (links_df['target'].isin(biggest_wcc_com))]
big_wcc_links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10115 entries, 0 to 11068
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   type         10115 non-null  object
#  1   weight       10114 non-null  float64
#  2   dataset      10115 non-null  object
#  3   source       10115 non-null  object
#  4   target       10115 non-null  object
#  5   key          10115 non-null  int64
#  6   weightlcoat  1 non-null      float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.2+ KB

# %% [markdown]
# Dijkstra

# %%
import itertools
import sys
from heapq import *

# %%
class Vertex:
    def __init__(self, name):
        self.key = name
        self.neighbor = {}
        self.cost = float("inf")
        self.predecessor = None
        self.pre_relationship = None
        self.pre_key = -1

    def add_neighbor(self, weight, vertex_name,key):
        # 有重边但是weight不一样，用key指示
        self.neighbor[(vertex_name,key)] = weight

    def add_pre(self, pre, relationship, key):
        self.predecessor = pre
        self.pre_relationship = relationship
        self.pre_key = key

# %%
def get_path(dst):
    result_path = []
    while dst.predecessor is not None:
        result_path.append(dst.key)
        result_path.append(dst.pre_relationship.values[0])
        result_path.append("key="+str(dst.pre_key))
        dst = dst.predecessor
    result_path.append(dst.key)
    return result_path

def clear_pre(all_ver):
    for ver in all_ver:
        all_ver[ver].predecessor = None
        all_ver[ver].cost = float("inf")

def dijkstra(source, destination, all_vertices):
    # path = {}
    counter = itertools.count()
    count_or = next(counter)
    heap = [(0, count_or, source)]
    heapify(heap)
    source.cost = 0
    visit = []

    while heap is not None:
        # get the top vertex of the heap update its cost to neighbors
        tmp_distance, tmp_order, tmp_vertex = heappop(heap)

        if tmp_vertex == destination:
            break

        visit.append(tmp_vertex.key)
        for neighbors in tmp_vertex.neighbor:
            # neighbors:(name,key)
            neighbor_name,neighbor_key=neighbors
            if neighbor_name not in visit:
                tmp_cost = tmp_distance + tmp_vertex.neighbor[neighbors]
                if tmp_cost < all_vertices[neighbor_name].cost:
                    relationship=big_wcc_links[(big_wcc_links['source']==tmp_vertex.key) & 
                                               (big_wcc_links['target']==neighbor_name)&
                                               (big_wcc_links['key']==neighbor_key)]['type']
                    # print(relationship)
                    all_vertices[neighbor_name].add_pre(tmp_vertex,relationship,neighbor_key)
                    all_vertices[neighbor_name].cost = tmp_cost
                    heappush(heap, (int(all_vertices[neighbor_name].cost), next(counter), all_vertices[neighbor_name]))

# %%
all_vertices = {}

for nodes in big_wcc_nodes['id']:
    all_vertices[nodes] = Vertex(nodes)
    
for links in big_wcc_links.iterrows():
    # print(links[1]['source'],links[1]['weight'],links[1]['target'])
    # dijkstra找小的走->权重大置信度大->更应该选择，用1减
    key=links[1]['key']
    all_vertices[links[1]['source']].add_neighbor(1-links[1]['weight'], links[1]['target'],key)

# %%
all_vertices
print("Kristin Jones" in all_vertices.keys())
# Out:
# True

# %%
# 试一下
clear_pre(all_vertices)
dijkstra(all_vertices["979893388"],all_vertices["8327"],all_vertices)
res=get_path(all_vertices["8327"])
for i in range(len(res)):
    print(res[-i-1])
# res
# Out:
# 979893388
# key=0
# ownership
# Erica Hamilton
# key=0
# partnership
# 160
# key=0
# membership
# 8327

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["979893388"],all_vertices["Mar de la Vida OJSC"],all_vertices)
res=get_path(all_vertices["Mar de la Vida OJSC"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 979893388
# key=0
# partnership
# Dana Goodwin
# key=0
# membership
# Turkish Sword Buoy Incorporated Forwading
# key=0
# membership
# Spanish Shrimp  Carriers
# key=0
# membership
# Ancla Azul Company Solutions
# key=0
# membership
# Mar de la Vida OJSC

# %%
# Ocean Fisheries Llc
clear_pre(all_vertices)
dijkstra(all_vertices["979893388"],all_vertices["Ocean Fisheries Llc"],all_vertices)
res=get_path(all_vertices["Ocean Fisheries Llc"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 979893388
# key=0
# partnership
# Dana Goodwin
# key=0
# membership
# Faroe Islands Shrimp Shark
# key=1
# family_relationship
# png xi  Line
# key=2
# family_relationship
# Ocean Fisheries Llc

# %%
# Ocean Fisheries Llc
clear_pre(all_vertices)
dijkstra(all_vertices["979893388"],all_vertices["Oceanfront Oasis Inc Carriers"],all_vertices)
res=get_path(all_vertices["Oceanfront Oasis Inc Carriers"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 979893388
# key=0
# ownership
# Oceanfront Oasis Inc Carriers

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["Mar de la Vida OJSC"],all_vertices["979893388"],all_vertices)
res=get_path(all_vertices["979893388"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# Mar de la Vida OJSC
# key=0
# family_relationship
# b8567859-bf54-49fd-8332-5775e19c65af
# key=1
# partnership
# Faroe Islands Shrimp Shark
# key=0
# partnership
# 979893388

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["8327"],all_vertices["979893388"],all_vertices)
res=get_path(all_vertices["979893388"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 8327
# key=0
# membership
# 435054320
# key=0
# family_relationship
# Mary Horton
# key=0
# family_relationship
# 979893388

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["FishEye International"],all_vertices["979893388"],all_vertices)
res=get_path(all_vertices["979893388"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# FishEye International
# key=0
# membership
# Federated
# key=0
# ownership
# 23990411
# key=0
# membership
# 979893388

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["79"],all_vertices["979893388"],all_vertices)
res=get_path(all_vertices["979893388"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 79
# key=0
# ownership
# png xi  Line
# key=0
# ownership
# 19
# key=0
# ownership
# SeaSpray Wave SRL Solutions
# key=3
# family_relationship
# 979893388

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["79"],all_vertices["78"],all_vertices)
res=get_path(all_vertices["78"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 79
# key=0
# ownership
# 138782226
# key=0
# membership
# Spanish Shrimp  Carriers
# key=0
# ownership
# 3506021
# key=0
# partnership
# 348079
# key=0
# partnership
# 78

# %%
clear_pre(all_vertices)
dijkstra(all_vertices["348079"],all_vertices["78"],all_vertices)
res=get_path(all_vertices["78"])
for i in range(len(res)):
    print(res[-i-1])
# Out:
# 348079
# key=0
# partnership
# 78
